# %%
import json
import pandas as pd

# %%
competitions = pd.read_json('competitions.json')

# %%
competitions_female = competitions[competitions['competition_gender'] == 'female']

# %%
competitions_female
# Out:
#     competition_id  season_id              country_name  \
# 15              37         90                   England
# 16              37         42                   England
# 17              37          4                   England
# 38              49          3  United States of America
# 41              53        106                    Europe
# 42              72         30             International
#
#            competition_name competition_gender  competition_youth  \
# 15  FA Women's Super League             female              False
# 16  FA Women's Super League             female              False
# 17  FA Women's Super League             female              False
# 38                     NWSL             female              False
# 41        UEFA Women's Euro             female              False
# 42        Women's World Cup             female              False
#
#     competition_international season_name               match_updated  \
# ...

# %%
data_72 = pd.read_json('matches/72/30.json')

# %%
data_72.head(50)
# Out:
#     match_id  match_date      kick_off  \
# 0      22963  2019-06-14  18:00:00.000
# 1      68311  2019-06-18  21:00:00.000
# 2      68357  2019-06-22  21:00:00.000
# 3      22933  2019-06-09  13:00:00.000
# 4      22940  2019-06-10  18:00:00.000
# 5      22943  2019-06-11  21:00:00.000
# 6      22944  2019-06-11  18:00:00.000
# 7      22945  2019-06-12  15:00:00.000
# 8      22949  2019-06-12  18:00:00.000
# 9      22956  2019-06-13  21:00:00.000
# 10     22961  2019-06-14  15:00:00.000
# 11     22964  2019-06-15  15:00:00.000
# 12     22966  2019-06-15  21:00:00.000
# 13     68344  2019-06-20  18:00:00.000
# 14     68345  2019-06-20  21:00:00.000
# 15     69163  2019-06-24  21:00:00.000
# 16     68346  2019-06-20  18:00:00.000
# 17     68355  2019-06-22  17:30:00.000
# 18     69301  2019-07-06  17:00:00.000
# 19     69137  2019-06-23  21:00:00.000
# 20     69208  2019-06-29  18:30:00.000
# 21     22936  2019-06-09  18:00:00.000
# 22     22973  2019-06-16  15:00:00.000
# ...
